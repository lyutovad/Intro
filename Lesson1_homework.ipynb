# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 201)
plt.plot(x, np.cos(x))

# %%
x = np.linspace(-np.pi, np.pi, 201)
plt.plot(x, np.cos(x*1.5))
